# %%
# Exercício criando uma nova base de dados

# %% [markdown]
# ## Importando as libs

# %%
import pandas as pd
import numpy as np
from pandas_datareader import data
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import yfinance as yf
import nbformat

# %%
acoes = ['ABEV','ODPV3.SA','VIV','PETR4.SA','BBAS3.SA','BOVA11.SA']
acoes_df = pd.DataFrame()

for acao in acoes:
    acoes_df[acao] = yf.download(acao, start='2015-01-01')['Close']

acoes_df
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                 ABEV   ODPV3.SA       VIV   PETR4.SA   BBAS3.SA   BOVA11.SA
# Date
# 2015-01-02  4.281933   5.826656  9.531738   2.779414   5.997846   47.259998
# 2015-01-05  4.202773   5.982119  9.337212   2.541857   5.873387   46.320000
# 2015-01-06  4.361095   5.938590  9.381674   2.458712   5.955478   46.580002
# 2015-01-07  4.433061   6.025646  9.603989   2.574522   6.217634   48.150002
# 2015-01-08  4.480106   6.006993  9.748498   2.740811   6.238819   48.509998
# ...              ...        ...       ...        ...        ...         ...
# ...

# %%
acoes_df.dropna()
acoes_df.shape
acoes_df.to_csv('acoes_ex.csv')
acoes_df.plot(figsize= (15, 7), title = "Histórico de preço")
# Out:
# <Axes: title={'center': 'Histórico de preço'}, xlabel='Date'>

# %%
acoes_df.describe()
# Out:
#               ABEV     ODPV3.SA          VIV     PETR4.SA     BBAS3.SA  \
# count  2537.000000  2444.000000  2537.000000  2444.000000  2444.000000
# mean      3.326990     9.548411     8.389634    11.429414    13.723630
# std       0.971140     1.688929     1.446065     9.791871     6.202728
# min       1.629595     5.826656     4.823659     1.247173     3.715400
# 25%       2.486783     8.215111     7.183297     4.529911     9.521307
# 50%       3.224400     9.864429     8.390119     7.935386    12.466107
# 75%       4.073900    10.861612     9.584288    14.695153    17.164919
# max       5.875072    13.353064    11.625198    37.689999    28.316017
#
#          BOVA11.SA
# count  2419.000000
# mean     89.327908
# std      26.240151
# min      36.450001
# 25%      64.215000
# 50%      96.400002
# 75%     111.084999
# max     133.619995
